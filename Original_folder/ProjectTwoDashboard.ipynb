# %%
from jupyter_dash import JupyterDash
import dash
import dash_leaflet
import plotly.express as px
import pandas as pd
print("All imports OK")

# %%
# Setup the Jupyter version of Dash
from jupyter_dash import JupyterDash

# Dash and related imports
import dash_leaflet as dl
from dash import dcc, html, dash_table
from dash.dependencies import Input, Output, State
import plotly.express as px
import base64

# Other libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import your CRUD class
from crud_module import CRUD

###########################
# Data Manipulation / Model
###########################
username = "aacuser"
password = "Sputnik1957"
shelter = CRUD(username, password)
host = "localhost"  
port = "27017"  
database = "aac" 
# Connect to database via CRUD Module
db = CRUD(username, password)

# Retrieve all documents initially
df = pd.DataFrame.from_records(db.read_query({}))

# Drop '_id' if present
if '_id' in df.columns:
    df.drop(columns=['_id'], inplace=True)

#########################
# Dashboard Layout / View
#########################
app = JupyterDash('GraziosoSalvareDashboard')

# Encode the Grazioso Salvare logo
image_filename = "Grazioso Salvare Logo.png"  # Ensure this file is in the same folder
encoded_image = base64.b64encode(open(image_filename, 'rb').read()).decode()

app.layout = html.Div([
    # Logo
    html.Img(src='data:image/png;base64,{}'.format(encoded_image), style={'height': '100px'}),
    # Title
    html.Center(html.B(html.H1('CS-340 Dashboard - [Aspen]'))),
    html.Hr(),

    # Filtering options (Radio buttons, etc.)
    html.Div([
    html.Label("Select Rescue Type:"),
    dcc.RadioItems(
        id='filter-type',
        options=[
            {'label': 'Reset', 'value': 'RESET'},
            {'label': 'Water Rescue', 'value': 'WATER'},
            {'label': 'Mountain or Wilderness Rescue', 'value': 'MOUNTAIN'},
            {'label': 'Disaster or Individual Tracking', 'value': 'DISASTER'},
        ],
        value='RESET',
        labelStyle={'display': 'inline-block', 'margin-right': '20px'}
    )
]),

    html.Hr(),

    # Data Table
    dash_table.DataTable(
        id='datatable-id',
        columns=[{"name": i, "id": i, "deletable": False, "selectable": True} for i in df.columns],
        data=df.to_dict('records'),
        page_size=10,
        style_table={'overflowX': 'auto'},
        row_selectable="single",
        selected_rows=[0],
        sort_action="native",
        filter_action="native"
    ),
    html.Br(),
    html.Hr(),

    # Row with chart and map side-by-side
    html.Div(
        className='row',
        style={'display': 'flex'},
        children=[
            html.Div(id='graph-id', className='col s12 m6'),
            html.Div(id='map-id', className='col s12 m6')
        ]
    )
])

#############################################
# Interaction Between Components / Controller
#############################################

# 1) Filter the data table based on rescue type
@app.callback(
    Output('datatable-id', 'data'),
    [Input('filter-type', 'value')]
)
def update_dashboard(filter_type):
    """
    Simple filtering logic based on the selected rescue type.
    Replace with your actual queries as needed.
    """
    if filter_type == 'RESET':
        query = {}
    elif filter_type == 'WATER':
        query = {"breed": {"$in": ["Labrador Retriever Mix", "Chesapeake Bay Retriever"]}}
    elif filter_type == 'MOUNTAIN':
        query = {"breed": {"$in": ["German Shepherd", "Alaskan Malamute"]}}
    elif filter_type == 'DISASTER':
        query = {"breed": {"$in": ["Doberman Pinscher", "Golden Retriever", "Border Collie"]}}
    else:
        query = {}

    records = db.read_query(query)

    dff = pd.DataFrame.from_records(records)

    if "_id" in dff.columns:
        dff.drop(columns=["_id"], inplace=True)

    return dff.to_dict('records')


# 2) Create a pie chart from the current table data
@app.callback(
    Output('graph-id', "children"),
    [Input('datatable-id', "derived_virtual_data")]
)
def update_graphs(viewData):
    if not viewData:
        return "No Data Available"
    # Group by breed, count how many rows per breed
    dff = pd.DataFrame.from_dict(viewData)
    dff_count = dff.groupby("breed")["breed"].count().reset_index(name="count")
    # Sort descending and keep the top 10
    dff_count = dff_count.sort_values("count", ascending=False).head(10)

    # Create the pie chart using the aggregated data
    fig = px.pie(
        dff_count,
        names="breed",
        values="count",
        title="Top 10 Breeds"
    )

    return [dcc.Graph(figure=fig)]
# 3) Highlight selected columns in the data table
@app.callback(
    Output('datatable-id', 'style_data_conditional'),
    [Input('datatable-id', 'selected_columns')]
)
def update_styles(selected_columns):
    if not selected_columns:  # if None or empty
        return []
    return [{
        'if': {'column_id': i},
        'background_color': '#D2F3FF'
    } for i in selected_columns]


# 4) Update the geo-location chart for the selected row
@app.callback(
    Output('map-id', "children"),
    [
        Input('datatable-id', "derived_virtual_data"),
        Input('datatable-id', "derived_virtual_selected_rows")
    ]
)
def update_map(viewData, selected_rows):
    if not viewData:
        return "No Data Available"

    dff = pd.DataFrame.from_dict(viewData)

    # If no row is selected, default to row = 0
    if not selected_rows:
        row = 0
    else:
        row = selected_rows[0]

    # Check for enough columns to reference lat/long
    if len(dff.columns) < 15:
        return "Not enough columns for lat/long."

    # Center on Henderson, NV [36.04, -114.98]
    return [
        dl.Map(
            style={'width': '1000px', 'height': '500px'},
            center=[36.04, -114.98],
            zoom=10,
            children=[
                dl.TileLayer(id="base-layer-id"),
                dl.Marker(
                    position=[dff.iloc[row, 13], dff.iloc[row, 14]],
                    
                    children=[
                        dl.Tooltip(str(dff.iloc[row, 4])),
                        dl.Popup([
                            html.H1("Animal Name"),
                            html.P(str(dff.iloc[row, 9]))
                        ])
                    ]
                )
            ]
        )
    ]


if __name__ == '__main__':
    app.run_server(debug=True, port=8050)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[4], line 33
#      30 db = CRUD(username, password)
#      32 # Retrieve all documents initially
# ---> 33 df = pd.DataFrame.from_records(db.read_query({}))
#      35 # Drop '_id' if present
#      36 if '_id' in df.columns:
#
# File ~\Downloads\CS340M7Project2\crud_module.py:10, in CRUD.read_query(self, query)
#       9 def read_query(self, query):
# ---> 10     return list(self.db.animals.find(query))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
#    1266     return self._data.popleft()
#    1267 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\cursor.py:1213, in Cursor._refresh(self)
#    1191         raise InvalidOperation(
#    1192             "Passing a 'hint' is required when using the min/max query"
#    1193             " option to ensure the query utilizes the correct index"
#    1194         )
#    1195     q = self._query_class(
#    1196         self._query_flags,
#    1197         self._collection.database.name,
#    (...)
#    1211         self._exhaust,
#    1212     )
# -> 1213     self._send_message(q)
#    1214 elif self._id:  # Get More
#    1215     if self._limit:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\cursor.py:1108, in Cursor._send_message(self, operation)
#    1105     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1107 try:
# -> 1108     response = client._run_operation(
#    1109         operation, self._unpack_response, address=self._address
#    1110     )
#    1111 except OperationFailure as exc:
#    1112     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1113         # Don't send killCursors because the cursor is already closed.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:1938, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1928     operation.reset()  # Reset op in case of retry.
#    1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    (...)
#    1935         self,
#    1936     )
# -> 1938 return self._retryable_read(
#    1939     _cmd,
#    1940     operation.read_preference,
#    1941     operation.session,  # type: ignore[arg-type]
#    1942     address=address,
#    1943     retryable=isinstance(operation, _Query),
#    1944     operation=operation.name,
#    1945 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:2048, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
#    2047 with self._tmp_session(session) as s:
# -> 2048     return self._retry_internal(
#    2049         func,
#    2050         s,
#    2051         None,
#    2052         operation,
#    2053         is_read=True,
#    2054         address=address,
#    2055         read_pref=read_pref,
#    2056         retryable=retryable,
#    2057         operation_id=operation_id,
#    2058     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:2908, in _ClientConnectionRetryable._read(self)
#    2903 def _read(self) -> T:
#    2904     """Wrapper method for read-type retryable client executions
#    2905
#    2906     :return: Output for func()'s call
#    2907     """
# -> 2908     self._server = self._get_server()
#    2909     assert self._read_pref is not None, "Read Preference required on read calls"
#    2910     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2911         conn,
#    2912         read_pref,
#    2913     ):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:2856, in _ClientConnectionRetryable._get_server(self)
#    2851 def _get_server(self) -> Server:
#    2852     """Retrieves a server object based on provided object context
#    2853
#    2854     :return: Abstraction to connect to server
#    2855     """
# -> 2856     return self._client._select_server(
#    2857         self._server_selector,
#    2858         self._session,
#    2859         self._operation,
#    2860         address=self._address,
#    2861         deprioritized_servers=self._deprioritized_servers,
#    2862         operation_id=self._operation_id,
#    2863     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)
#     425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)
#     400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: nv-desktop-services.apporto.com:33016: [Errno 11001] getaddrinfo failed (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6963168483c3eb62f4ec8662, topology_type: Unknown, servers: [<ServerDescription ('nv-desktop-services.apporto.com', 33016) server_type: Unknown, rtt: None, error=AutoReconnect('nv-desktop-services.apporto.com:33016: [Errno 11001] getaddrinfo failed (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
import sys
print(sys.executable)

import pymongo, pandas
print("pymongo:", pymongo.__version__)
print("pandas:", pandas.__version__)
# Out:
# C:\Users\aspen\AppData\Local\Programs\Python\Python310\python.exe
# pymongo: 4.16.0
# pandas: 2.3.3

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")
print(client.admin.command("ping"))
# Out:
# {'ok': 1.0}

# %%
db = client["aac"]
print("Collections:", db.list_collection_names())
print("Animal count:", db.animals.count_documents({}))
# Out:
# Collections: []
# Animal count: 0
